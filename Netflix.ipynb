# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_netflix = pd.read_csv("Netflix Dataset.csv")
df_netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df_netflix.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df_netflix.size #total number of element in dataset
# Out:
# 85679

# %%
df_netflix.shape
# Out:
# (7789, 11)

# %%
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df_netflix[df_netflix.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df_netflix.drop_duplicates(inplace=True)

# %%
df_netflix[df_netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
nan_df = df_netflix[df_netflix.isna().any(axis=1)]
nan_df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 11       s12  TV Show                                     1983
# 12       s13  TV Show                                     1994
# 16       s17  TV Show                                   Feb-09
# 19       s20    Movie                                      '89
# ...      ...      ...                                      ...
# 7779   s7778  TV Show                              Zombie Dumb
# 7781   s7780  TV Show                                Zona Rosa
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                   Director                                               Cast  \
# 0                      NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#heatmap to see null value

# %%
sns.heatmap(df_netflix.isnull())

# %% [markdown]
# #### #director have multiple null values also few null values incast, country and relese data

# %% [markdown]
# ## Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df_netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# using str.conatins

HOC = df_netflix[df_netflix.Title.str.contains("House of Cards")]

# %%
HOC.Show_Id
# Out:
# 2832    s2833
# Name: Show_Id, dtype: object

# %%
HOC.Director
# Out:
# 2832    Robin Wright, David Fincher, Gerald McRaney, J...
# Name: Director, dtype: object

# %%
#Using isin function
df_netflix[df_netflix.Title.isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
df_netflix['Release_Date'] = pd.to_datetime(df_netflix['Release_Date'])

# %%
df_netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
df_netflix['Year'] = df_netflix['Release_Date'].dt.year

# %%
year_shows = df_netflix['Year'].value_counts()

# %%
year_shows.plot(kind = 'bar')

# %% [markdown]
# ## Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
count_category = df_netflix.groupby("Category").count()

# %%
sns.countplot(df_netflix.Category)

# %% [markdown]
# ## Q. 4) Show all the Movies that were released in year 2000.

# %%
df_netflix[(df_netflix.Category == 'Movie') & (df_netflix.Year == 2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Year]
# Index: []

# %%
df_netflix.Year.unique()
# Out:
# array([2020., 2016., 2018., 2017., 2019., 2021., 2015., 2013., 2011.,
#          nan, 2012., 2014., 2008., 2009., 2010.])

# %%
df_netflix[(df_netflix.Category == 'Movie') & (df_netflix.Year == 2013)]
# Out:
#      Show_Id Category                        Title  \
# 220     s221    Movie   A Russell Peters Christmas
# 649     s650    Movie    Aziz Ansari: Buried Alive
# 2948   s2949    Movie  Iliza Shlesinger: War Paint
# 5315   s5315    Movie    Russell Peters: Notorious
# 5588   s5588    Movie            Shrek the Musical
# 6866   s6865    Movie               The Short Game
#
#                            Director  \
# 220              Henry Sarwer-Foner
# 649   Will Lovelace, Dylan Southern
# 2948                    Jay Chapman
# 5315                     Dave Higby
# 5588                    Jason Moore
# 6866                 Josh Greenbaum
#
#                                                    Cast        Country  \
# 220   Russell Peters, Pamela Anderson, Michael Bublé...         Canada
# 649                                         Aziz Ansari  United States
# 2948                                   Iliza Shlesinger  United States
# ...

# %% [markdown]
# ## Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df_netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Year'],
#       dtype='object')

# %%
show_India = df_netflix[(df_netflix.Category == 'TV Show') & (df_netflix.Country == 'India')]

# %%
show_India['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ## Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df_netflix.Director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: Director, dtype: int64

# %% [markdown]
# ## Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df_netflix.Type.unique
# Out:
# <bound method Series.unique of 0       International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                            Dramas, International Movies
# 2                     Horror Movies, International Movies
# 3       Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                  Dramas
#                               ...
# 7784                         Dramas, International Movies
# 7785       Dramas, International Movies, Music & Musicals
# 7786    Documentaries, International Movies, Music & M...
# 7787                   International TV Shows, Reality TV
# 7788                      Documentaries, Music & Musicals
# Name: Type, Length: 7787, dtype: object>

# %%
df_netflix[df_netflix.Type == 'Comedies']
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
record1 = df_netflix[((df_netflix.Category == 'Movie') & (df_netflix.Type == 'Comedies')) | (df_netflix.Country == 'United Kingdom')]

# %%
record1
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
record = df_netflix[((df_netflix.Category == 'Movie') & (df_netflix.Type.str.contains('Comedies'))) | (df_netflix.Country == 'United Kingdom') ]

# %%
record
# Out:
#      Show_Id Category                              Title            Director  \
# 18       s19    Movie                             15-Aug  Swapnaneel Jayakar
# 19       s20    Movie                                '89                 NaN
# 33       s34    Movie                       #realityhigh    Fernando Lebrija
# 34       s35    Movie                              #Roxy     Michael Kennedy
# 36       s37    Movie                            #Selfie      Cristina Jacob
# ...      ...      ...                                ...                 ...
# 7766   s7765    Movie                               Zero          Aanand Rai
# 7771   s7770    Movie           Zindagi Na Milegi Dobara         Zoya Akhtar
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan        Oskar Santos
# 7780   s7779    Movie                         Zombieland     Ruben Fleischer
# 7783   s7782    Movie                               Zoom        Peter Hewitt
#
# ...

# %% [markdown]
# ## Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df_netflix.Cast = df_netflix.Cast.fillna("")

# %%
df_netflix.Cast.str.contains('Tom Cruise')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Cast, Length: 7787, dtype: bool

# %%
df_netflix[df_netflix.Cast.str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    Year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# ## Q. 9) What are the different Ratings defined by Netflix ?

# %%
df_netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Year'],
#       dtype='object')

# %%
df_netflix.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df_netflix.Rating.value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %% [markdown]
# ## Q.9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
rating_can = df_netflix[(df_netflix.Category == 'Movie') & (df_netflix.Rating == 'TV-14') & (df_netflix.Country == 'Canada')  ]

# %%
rating_can.head()
# Out:
#      Show_Id Category                       Title  \
# 30       s31    Movie            #cats_the_mewvie
# 34       s35    Movie                       #Roxy
# 608     s609    Movie              At First Light
# 1506   s1507    Movie  Counterfeiting in Suburbia
# 3713   s3714    Movie           Long Time Running
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
#
#                                                    Cast Country Release_Date  \
# 30                                                       Canada   2020-02-05
# 34    Jake Short, Sarah Fisher, Booboo Stewart, Dann...  Canada   2019-04-10
# 608   Stefanie Scott, Theodore Pellerin, Percy Hynes...  Canada   2018-12-27
# ...

# %%
rating_can.shape
# Out:
# (11, 12)

# %% [markdown]
# ## Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
rating_2018 = df_netflix[(df_netflix.Category == 'TV Show') & (df_netflix.Rating == 'R') & (df_netflix.Year > 2018 ) ]

# %%
rating_2018
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description    Year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %%
rating_2018.shape
# Out:
# (1, 12)

# %% [markdown]
# ## Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df_time_min = df_netflix[~df_netflix.Duration.str.contains('Season')]

# %%
df_time_min.Duration = df_time_min.Duration.str.replace(' min',"")

# %%
df_time_min.Duration = df_time_min.Duration.astype(int)

# %%
df_time_min[df_time_min.Duration == df_time_min.Duration.max()]
# Out:
#     Show_Id Category                       Title Director  \
# 957    s958    Movie  Black Mirror: Bandersnatch      NaN
#
#                                                   Cast        Country  \
# 957  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#     Release_Date Rating  Duration  \
# 957   2018-12-28  TV-MA       312
#
#                                                Type  \
# 957  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                            Description    Year
# 957  In 1984, a young programmer begins to question...  2018.0

# %%
df_netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Year'],
#       dtype='object')

# %%
df=df_netflix.copy()

# %%
df[['Time','Unit']] = df_netflix.Duration.str.split(" ",expand= True)

# %%
df.Time = df.Time.astype(int)

# %%
max_time = df[df.Unit.str.contains("min")].Time.max()

# %%
df[(df.Time == max_time) & (df.Unit.str.contains("min"))]
# Out:
#     Show_Id Category                       Title Director  \
# 957    s958    Movie  Black Mirror: Bandersnatch      NaN
#
#                                                   Cast        Country  \
# 957  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#     Release_Date Rating Duration  \
# 957   2018-12-28  TV-MA  312 min
#
#                                                Type  \
# 957  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                            Description    Year  Time Unit
# 957  In 1984, a young programmer begins to question...  2018.0   312  min

# %%
#max season

# %%
df.Unit.unique()
# Out:
# array(['Seasons', 'min', 'Season'], dtype=object)

# %%
max_seson = df[df.Unit.str.contains("Season")].Time.max()

# %%
df[(df.Time == max_seson) & (df.Unit.str.contains("Season"))]
# Out:
#      Show_Id Category           Title Director  \
# 2538   s2539  TV Show  Grey's Anatomy      NaN
#
#                                                    Cast        Country  \
# 2538  Ellen Pompeo, Sandra Oh, Katherine Heigl, Just...  United States
#
#      Release_Date Rating    Duration                          Type  \
# 2538   2020-05-09  TV-14  16 Seasons  Romantic TV Shows, TV Dramas
#
#                                             Description    Year  Time     Unit
# 2538  Intern (and eventual resident) Meredith Grey f...  2020.0    16  Seasons

# %% [markdown]
# ## Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
df_tvshow = df_netflix[df_netflix.Category == 'TV Show']

# %%
df_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ## Q. 12) How can we sort the dataset by Year ?

# %%
df_netflix.sort_values('Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %% [markdown]
# ## Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df_netflix[((df_netflix.Category == 'Movie') & (df_netflix.Type == 'Dramas')) | ((df_netflix.Category == 'TV Show') & (df_netflix.Type == "Kids' TV"))]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
